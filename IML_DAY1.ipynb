# %% [markdown]
# <a href="https://colab.research.google.com/github/subrat21112006/IML_ALL/blob/main/IML_DAY1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
count=0
n=int(input("enter the num"))
if(n==0):
  print("enter the accurate num in bet-- 1 to fur..")

for i in range(1,n+1):
  if(n%i==0):
    count=count+1
if(count==2):
    print("prime")
else:
  print("not prime")
# Out:
# enter the num45
# not prime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
fact=1
num=int(input("enter num"))
for i in range(1,num+1):
  fact*=i
print(fact)
# Out:
# enter num4
# 24

# %%
a=1
b=2
print("value of a before ",a)
print("value of b before ",b)

a=b
b=a
print("after excange a",a)
print("after exchange b",b)
# Out:
# value of a before  1
# value of b before  2
# after excange a 2
# after exchange b 2

# %%
num=int(input("enter a num"))
print({True: "positive",
       False: {True: "negative", False: "zero"}[num < 0]}[num > 0])
# Out:
# enter a num1
# positive

# %%
num=int(input("enter a num"))
if(n<0):
  print("enter the num 1 to upper")
else:
  rev=0
  t=n
  if(n>1):
    r=n%10
    rev=rev*10+r
    n=n/10

  if(t==rev):
    print("palindrom")
  else:
    print("not palindrom")
# Out:
# enter a num121
# palindrom
